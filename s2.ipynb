# %%
import numpy as np

# %%
# 1.Create a 2D NumPy array representing the ratings (out of 5) given by 4 users to 5 different food items on Zomato. Use slicing to extract the ratings given by the second and third users only.

# %%
np.array([
    [4, 5, 3, 4, 5],
    [5, 4, 4, 3, 5],
    [3, 5, 4, 5, 4],
    [4, 3, 5, 4, 3]
])
# Out:
# array([[4, 5, 3, 4, 5],
#        [5, 4, 4, 3, 5],
#        [3, 5, 4, 5, 4],
#        [4, 3, 5, 4, 3]])

# %%
ratings = np.array([
    [4, 5, 3, 4, 5],
    [5, 4, 4, 3, 5],
    [3, 5, 4, 5, 4],
    [4, 3, 5, 4, 3]
])

# %%
ratings
# Out:
# array([[4, 5, 3, 4, 5],
#        [5, 4, 4, 3, 5],
#        [3, 5, 4, 5, 4],
#        [4, 3, 5, 4, 3]])

# %%
ratings[1:3]
# Out:
# array([[5, 4, 4, 3, 5],
#        [3, 5, 4, 5, 4]])

# %%
# 2.Given a NumPy array of daily steps tracked for 10 days, use boolean indexing to select only the days where the steps were greater than 8000.<br><br><em><strong>Hint:</strong> Use an array like steps = np.array([7500, 8200, 9000, ...]) and apply a boolean condition.</em>

# %%
np.array([7500, 8200, 9000, 6500, 10500, 7800, 8500, 9200, 7000, 11000])
# Out:
# array([ 7500,  8200,  9000,  6500, 10500,  7800,  8500,  9200,  7000,
#        11000])

# %%
steps = np.array([7500, 8200, 9000, 6500, 10500, 7800, 8500, 9200, 7000, 11000])

# %%
steps
# Out:
# array([ 7500,  8200,  9000,  6500, 10500,  7800,  8500,  9200,  7000,
#        11000])

# %%
high_steps = steps[steps > 8000]

# %%
high_steps
# Out:
# array([ 8200,  9000, 10500,  8500,  9200, 11000])

# %%
# 3.Create a NumPy array of IPL team scores for 8 matches. Use fancy indexing to select the scores from matches 2, 5, and 7, and print them.

# %%
np.array([180, 195, 165, 210, 175, 190, 220, 185])
# Out:
# array([180, 195, 165, 210, 175, 190, 220, 185])

# %%
scores = np.array([180, 195, 165, 210, 175, 190, 220, 185])

# %%
scores
# Out:
# array([180, 195, 165, 210, 175, 190, 220, 185])

# %%
scores[[1, 4, 6]]
# Out:
# array([195, 175, 220])

# %%
selected_scores = scores[[1, 4, 6]]

# %%
selected_scores
# Out:
# array([195, 175, 220])

# %%
# 4.Suppose you have a NumPy array of product prices from Flipkart. Use broadcasting to apply a 10% discount to all prices and print the new array.<br><br><em><strong>Constraint:</strong> Do not use any loops.</em>

# %%
np.array([500, 1000, 1500, 2000, 2500])
# Out:
# array([ 500, 1000, 1500, 2000, 2500])

# %%
prices = np.array([500, 1000, 1500, 2000, 2500])

# %%
prices
# Out:
# array([ 500, 1000, 1500, 2000, 2500])

# %%
prices*10/100
# Out:
# array([ 50., 100., 150., 200., 250.])

# %%
discounted_prices = prices*10/100

# %%
prices-discounted_prices
# Out:
# array([ 450.,  900., 1350., 1800., 2250.])

# %%
# 5.Given a NumPy array of user ratings (can be negative, zero, or positive) for songs on Spotify, use boolean masking to set all negative ratings to zero, keeping other ratings unchanged.

# %%
np.array([-2, 5, 0, -1, 4, -3, 2])
# Out:
# array([-2,  5,  0, -1,  4, -3,  2])

# %%
ratings = np.array([-2, 5, 0, -1, 4, -3, 2])

# %%
ratings
# Out:
# array([-2,  5,  0, -1,  4, -3,  2])

# %%
ratings < 0
# Out:
# array([ True, False, False,  True, False,  True, False])

# %%
ratings[ratings < 0] = 0

# %%
ratings
# Out:
# array([0, 5, 0, 0, 4, 0, 2])
